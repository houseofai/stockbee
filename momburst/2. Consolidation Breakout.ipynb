# %%
import numpy as np
import pickle

# Ensure the plotting backend is set correctly
# %matplotlib inline

# %%
backup_file = 'data/grouped_dfs.pkl'
try:
    with open(backup_file, 'rb') as f:
        grouped_dfs = pickle.load(f)
except FileNotFoundError:
    print('Backup file not found. Rebuilding the data.')

# %% [markdown]
# # Spot MB

# %% [markdown]
# ### Continuation Setup
# - Focus on the 2nd or 3rd breakout
# - Stock close near the high
# - Day before the breakout, negative or small up day
# - 3 to 10 days
# - Not Up 2 days in the row
# - Highest probability of success
# - 2lynch

# %%
df_wwww = grouped_dfs['WWW']['2022-12-03':'2023-02-21']
df_wwww.to_csv('data/wwww.csv')

# %%
df_amgn = grouped_dfs['AMGN']['2022-10-17':'2023-11-14']
df_tree = grouped_dfs['TREE']['2022-12-12':'2023-02-27']
df_fslr = grouped_dfs['FSLR']['2022-10-03':'2023-01-01']

# %% [markdown]
# #### 2 Lynch

# %%
mb_tests = {
    'AMGN': df_amgn,
    'TREE': df_tree,
    'FSLR': df_fslr,
    'WWW': df_wwww
}

# %%
# Input values
candle_body_threshold = 0.6
open_to_high_threshold = 2.0
volume_sma_length = 20
high_lookback_period_10 = 10
high_lookback_period_5 = 5
low_lookback_period_20 = 20
low_threshold_percentage = 10.0
low_above_lookback_low_percentage = 5.0
move_threshold = 4.0

# %%
def is_narrow(df_):
    # rename columns to lowercase
    df_.columns = df_.columns.str.lower()
    # Calculate candle body percentage and open to high percentage
    df_['candle_body_percentage'] = np.abs(df_['close'] - df_['open']) / df_['open'] * 100
    df_['open_to_high_percentage'] = (df_['high'] - df_['open']) / df_['open'] * 100
    
    # Calculate average volume
    df_['avg_volume'] = df_['volume'].rolling(window=volume_sma_length).mean()
    
    # Calculate the highest high over the last 10 days
    df_['highest_high_last_10_days'] = df_['high'].rolling(window=high_lookback_period_10).max()
    
    # Calculate the highest high over the last 5 days
    df_['highest_high_last_5_days'] = df_['high'].rolling(window=high_lookback_period_5).max()
    
    # Calculate the lowest low over the last 20 days
    df_['lowest_low_last_20_days'] = df_['low'].rolling(window=low_lookback_period_20).min()
    
    # Calculate the low threshold value
    df_['low_threshold_value'] = df_['highest_high_last_10_days'] * (1 - low_threshold_percentage / 100)
    
    # Calculate the threshold where the low must be above the lowest low of the last 20 days
    df_['low_above_lookback_low_value'] = df_['lowest_low_last_20_days'] * (1 + low_above_lookback_low_percentage / 100)
    
    # Condition for identifying narrow candles
    df_['is_narrow_candle'] = (
        (df_['candle_body_percentage'] < candle_body_threshold) & 
        (df_['open_to_high_percentage'] < open_to_high_threshold) & 
        (df_['volume'] < df_['avg_volume']) &
        (df_['low'] >= df_['low_threshold_value']) &
        (df_['high'] < df_['highest_high_last_5_days']) &
        (df_['low'] > df_['low_above_lookback_low_value'])
    )
    return df_

# %%
df_amgn
# Out:
# Price            Close        High         Low        Open     Volume
# Date
# 2022-10-17  252.929993  253.419998  249.490005  251.419998  2577100.0
# 2022-10-18  252.119995  254.699997  251.029999  253.860001  2060000.0
# 2022-10-19  248.190002  252.350006  246.940002  251.309998  1883000.0
# 2022-10-20  247.449997  249.059998  246.009995  247.550003  2058000.0
# 2022-10-21  251.940002  252.389999  247.009995  247.520004  3531200.0
# ...                ...         ...         ...         ...        ...
# 2023-11-08  273.260010  274.769989  270.750000  272.420013  1916800.0
# 2023-11-09  264.059998  273.230011  263.700012  272.130005  2266000.0
# 2023-11-10  267.309998  267.940002  262.510010  266.640015  2070600.0
# 2023-11-13  266.690002  267.220001  263.519989  265.679993  1579800.0
# 2023-11-14  270.019989  272.950012  268.359985  269.220001  2060000.0
#
# [272 rows x 5 columns]

# %%
df_amgn = is_narrow(df_amgn)
df_amgn
# Out:
# C:\Users\otrem\AppData\Local\Temp\ipykernel_6324\3751688661.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_['candle_body_percentage'] = np.abs(df_['close'] - df_['open']) / df_['open'] * 100
# C:\Users\otrem\AppData\Local\Temp\ipykernel_6324\3751688661.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_['open_to_high_percentage'] = (df_['high'] - df_['open']) / df_['open'] * 100
# C:\Users\otrem\AppData\Local\Temp\ipykernel_6324\3751688661.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_['avg_volume'] = df_['volume'].rolling(window=volume_sma_length).mean()
# C:\Users\otrem\AppData\Local\Temp\ipykernel_6324\3751688661.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_['highest_high_last_10_days'] = df_['high'].rolling(window=high_lookback_period_10).max()
# C:\Users\otrem\AppData\Local\Temp\ipykernel_6324\3751688661.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_['highest_high_last_5_days'] = df_['high'].rolling(window=high_lookback_period_5).max()
# C:\Users\otrem\AppData\Local\Temp\ipykernel_6324\3751688661.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_['lowest_low_last_20_days'] = df_['low'].rolling(window=low_lookback_period_20).min()
# C:\Users\otrem\AppData\Local\Temp\ipykernel_6324\3751688661.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_['low_threshold_value'] = df_['highest_high_last_10_days'] * (1 - low_threshold_percentage / 100)
# C:\Users\otrem\AppData\Local\Temp\ipykernel_6324\3751688661.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_['low_above_lookback_low_value'] = df_['lowest_low_last_20_days'] * (1 + low_above_lookback_low_percentage / 100)
# C:\Users\otrem\AppData\Local\Temp\ipykernel_6324\3751688661.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_['is_narrow_candle'] = (
# Price            close        high         low        open     volume  \
# Date
# 2022-10-17  252.929993  253.419998  249.490005  251.419998  2577100.0
# 2022-10-18  252.119995  254.699997  251.029999  253.860001  2060000.0
# 2022-10-19  248.190002  252.350006  246.940002  251.309998  1883000.0
# 2022-10-20  247.449997  249.059998  246.009995  247.550003  2058000.0
# 2022-10-21  251.940002  252.389999  247.009995  247.520004  3531200.0
# ...                ...         ...         ...         ...        ...
# 2023-11-08  273.260010  274.769989  270.750000  272.420013  1916800.0
# 2023-11-09  264.059998  273.230011  263.700012  272.130005  2266000.0
# 2023-11-10  267.309998  267.940002  262.510010  266.640015  2070600.0
# 2023-11-13  266.690002  267.220001  263.519989  265.679993  1579800.0
# 2023-11-14  270.019989  272.950012  268.359985  269.220001  2060000.0
#
# Price       candle_body_percentage  open_to_high_percentage  avg_volume  \
# Date
# 2022-10-17                0.600586                 0.795482         NaN
# 2022-10-18                0.685419                 0.330890         NaN
# 2022-10-19                1.241493                 0.413835         NaN
# 2022-10-20                0.040398                 0.609976         NaN
# 2022-10-21                1.785714                 1.967516         NaN
# ...                            ...                      ...         ...
# 2023-11-08                0.308346                 0.862630   2716170.0
# 2023-11-09                2.965497                 0.404221   2676840.0
# 2023-11-10                0.251269                 0.487544   2606710.0
# 2023-11-13                0.380160                 0.579648   2562730.0
# 2023-11-14                0.297150                 1.385488   2522570.0
#
# Price       highest_high_last_10_days  highest_high_last_5_days  \
# Date
# 2022-10-17                        NaN                       NaN
# 2022-10-18                        NaN                       NaN
# 2022-10-19                        NaN                       NaN
# 2022-10-20                        NaN                       NaN
# 2022-10-21                        NaN                254.699997
# ...                               ...                       ...
# 2023-11-08                 274.950012                274.950012
# 2023-11-09                 274.950012                274.950012
# 2023-11-10                 274.950012                274.950012
# 2023-11-13                 274.950012                274.769989
# 2023-11-14                 274.950012                274.769989
#
# Price       lowest_low_last_20_days  low_threshold_value  \
# Date
# 2022-10-17                      NaN                  NaN
# 2022-10-18                      NaN                  NaN
# 2022-10-19                      NaN                  NaN
# 2022-10-20                      NaN                  NaN
# 2022-10-21                      NaN                  NaN
# ...                             ...                  ...
# 2023-11-08               249.699997           247.455011
# 2023-11-09               249.699997           247.455011
# 2023-11-10               249.699997           247.455011
# 2023-11-13               249.699997           247.455011
# 2023-11-14               249.699997           247.455011
#
# Price       low_above_lookback_low_value  is_narrow_candle
# Date
# 2022-10-17                           NaN             False
# 2022-10-18                           NaN             False
# 2022-10-19                           NaN             False
# 2022-10-20                           NaN             False
# 2022-10-21                           NaN             False
# ...                                  ...               ...
# 2023-11-08                    262.184997              True
# 2023-11-09                    262.184997             False
# 2023-11-10                    262.184997              True
# 2023-11-13                    262.184997              True
# 2023-11-14                    262.184997              True
#
# [272 rows x 14 columns]

# %%
# rows where is narrow candle is True
df_amgn[df_amgn['is_narrow_candle']]
# Out:
# Price            close        high         low        open     volume  \
# Date
# 2022-11-16  283.769989  286.989990  282.559998  284.019989  2443500.0
# 2022-11-29  281.989990  283.380005  279.679993  283.380005  2135300.0
# 2022-12-02  285.510010  286.119995  283.190002  284.059998  2267000.0
# 2023-04-11  251.429993  253.080002  250.979996  251.419998  1272800.0
# 2023-04-14  250.000000  251.759995  248.960007  250.619995  1866200.0
# 2023-04-19  246.210007  246.759995  244.369995  245.250000  1246500.0
# 2023-06-20  228.589996  230.839996  227.190002  229.029999  2492700.0
# 2023-06-21  227.039993  230.000000  225.589996  228.179993  2282600.0
# 2023-07-24  235.419998  236.130005  233.919998  235.000000  1771300.0
# 2023-07-25  235.309998  236.570007  234.279999  234.360001  1325600.0
# 2023-07-26  235.210007  235.740005  232.440002  233.949997  1576800.0
# 2023-07-28  236.369995  238.179993  235.089996  236.820007  1889500.0
# 2023-08-09  259.320007  263.769989  259.119995  259.920013  2428100.0
# 2023-08-11  262.510010  264.109985  260.829987  261.700012  1560600.0
# 2023-08-14  260.970001  263.470001  259.850006  262.220001  1966100.0
# 2023-08-17  263.850006  266.579987  263.269989  263.869995  2256100.0
# 2023-08-21  260.700012  262.470001  259.010010  261.579987  2324100.0
# 2023-08-24  256.619995  260.190002  256.170013  256.730011  1888900.0
# 2023-08-25  256.380005  257.739990  254.809998  257.109985  1786600.0
# 2023-08-28  256.549988  258.119995  255.139999  256.959991  1661300.0
# 2023-09-22  267.700012  269.500000  266.519989  267.670013  1894100.0
# 2023-09-25  266.859985  267.809998  265.010010  267.540009  1705300.0
# 2023-10-02  266.309998  268.489990  264.380005  267.709991  1912300.0
# 2023-10-19  280.600006  283.209991  278.100006  282.089996  2536400.0
# 2023-11-08  273.260010  274.769989  270.750000  272.420013  1916800.0
# 2023-11-10  267.309998  267.940002  262.510010  266.640015  2070600.0
# 2023-11-13  266.690002  267.220001  263.519989  265.679993  1579800.0
# 2023-11-14  270.019989  272.950012  268.359985  269.220001  2060000.0
#
# Price       candle_body_percentage  open_to_high_percentage  avg_volume  \
# Date
# 2022-11-16                0.088022                 1.045701   3089755.0
# 2022-11-29                0.490513                 0.000000   2956430.0
# 2022-12-02                0.510460                 0.725198   3130350.0
# 2023-04-11                0.003975                 0.660251   2598300.0
# 2023-04-14                0.247385                 0.454872   2473830.0
# 2023-04-19                0.391440                 0.615696   2109015.0
# 2023-06-20                0.192116                 0.790288   2861570.0
# 2023-06-21                0.499605                 0.797619   2883270.0
# 2023-07-24                0.178723                 0.480853   2702980.0
# 2023-07-25                0.405358                 0.942997   2640985.0
# 2023-07-26                0.538581                 0.765124   2584530.0
# 2023-07-28                0.190023                 0.574270   2594800.0
# 2023-08-09                0.230843                 1.481216   2964180.0
# 2023-08-11                0.309514                 0.920891   2945790.0
# 2023-08-14                0.476699                 0.476699   2941635.0
# 2023-08-17                0.007575                 1.027018   2885215.0
# 2023-08-21                0.336407                 0.340246   2584525.0
# 2023-08-24                0.042853                 1.347716   2610725.0
# 2023-08-25                0.283918                 0.245033   2605580.0
# 2023-08-28                0.159559                 0.451434   2547315.0
# 2023-09-22                0.011207                 0.683673   2276675.0
# 2023-09-25                0.254176                 0.100915   2272610.0
# 2023-10-02                0.522952                 0.291360   2381265.0
# 2023-10-19                0.528197                 0.397035   2579770.0
# 2023-11-08                0.308346                 0.862630   2716170.0
# 2023-11-10                0.251269                 0.487544   2606710.0
# 2023-11-13                0.380160                 0.579648   2562730.0
# 2023-11-14                0.297150                 1.385488   2522570.0
#
# Price       highest_high_last_10_days  highest_high_last_5_days  \
# Date
# 2022-11-16                 296.670013                294.480011
# 2022-11-29                 291.600006                289.540009
# 2022-12-02                 291.600006                288.279999
# 2023-04-11                 256.440002                256.440002
# 2023-04-14                 256.440002                256.440002
# 2023-04-19                 256.440002                251.899994
# 2023-06-20                 231.949997                231.949997
# 2023-06-21                 231.949997                231.949997
# 2023-07-24                 238.479996                238.479996
# 2023-07-25                 238.479996                238.479996
# 2023-07-26                 238.479996                238.479996
# 2023-07-28                 238.479996                238.479996
# 2023-08-09                 263.790009                263.790009
# 2023-08-11                 264.779999                264.779999
# 2023-08-14                 264.779999                264.779999
# 2023-08-17                 268.239990                268.239990
# 2023-08-21                 268.239990                268.239990
# 2023-08-24                 268.239990                262.989990
# 2023-08-25                 268.239990                262.470001
# 2023-08-28                 268.239990                260.399994
# 2023-09-22                 273.079987                273.079987
# 2023-09-25                 273.079987                273.079987
# 2023-10-02                 273.609985                273.609985
# 2023-10-19                 288.459991                288.459991
# 2023-11-08                 274.950012                274.950012
# 2023-11-10                 274.950012                274.950012
# 2023-11-13                 274.950012                274.769989
# 2023-11-14                 274.950012                274.769989
#
# Price       lowest_low_last_20_days  low_threshold_value  \
# Date
# 2022-11-16               246.009995           267.003012
# 2022-11-29               259.839996           262.440005
# 2022-12-02               259.839996           262.440005
# 2023-04-11               228.520004           230.796002
# 2023-04-14               228.520004           230.796002
# 2023-04-19               229.589996           230.796002
# 2023-06-20               211.710007           208.754997
# 2023-06-21               211.710007           208.754997
# 2023-07-24               218.440002           214.631996
# 2023-07-25               218.440002           214.631996
# 2023-07-26               218.440002           214.631996
# 2023-07-28               218.440002           214.631996
# 2023-08-09               224.339996           237.411008
# 2023-08-11               224.339996           238.301999
# 2023-08-14               227.399994           238.301999
# 2023-08-17               228.210007           241.415991
# 2023-08-21               228.210007           241.415991
# 2023-08-24               228.210007           241.415991
# 2023-08-25               228.210007           241.415991
# 2023-08-28               228.210007           241.415991
# 2023-09-22               248.380005           245.771988
# 2023-09-25               248.380005           245.771988
# 2023-10-02               248.380005           246.248987
# 2023-10-19               259.670013           259.613992
# 2023-11-08               249.699997           247.455011
# 2023-11-10               249.699997           247.455011
# 2023-11-13               249.699997           247.455011
# 2023-11-14               249.699997           247.455011
#
# Price       low_above_lookback_low_value  is_narrow_candle
# Date
# 2022-11-16                    258.310494              True
# 2022-11-29                    272.831996              True
# 2022-12-02                    272.831996              True
# 2023-04-11                    239.946004              True
# 2023-04-14                    239.946004              True
# 2023-04-19                    241.069496              True
# 2023-06-20                    222.295507              True
# 2023-06-21                    222.295507              True
# 2023-07-24                    229.362003              True
# 2023-07-25                    229.362003              True
# 2023-07-26                    229.362003              True
# 2023-07-28                    229.362003              True
# 2023-08-09                    235.556996              True
# 2023-08-11                    235.556996              True
# 2023-08-14                    238.769994              True
# 2023-08-17                    239.620507              True
# 2023-08-21                    239.620507              True
# 2023-08-24                    239.620507              True
# 2023-08-25                    239.620507              True
# 2023-08-28                    239.620507              True
# 2023-09-22                    260.799005              True
# 2023-09-25                    260.799005              True
# 2023-10-02                    260.799005              True
# 2023-10-19                    272.653514              True
# 2023-11-08                    262.184997              True
# 2023-11-10                    262.184997              True
# 2023-11-13                    262.184997              True
# 2023-11-14                    262.184997              True
